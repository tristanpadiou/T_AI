# %%
from __future__ import annotations
import requests
import httpx
from pydantic_ai import Agent, RunContext, format_as_xml
from pydantic_ai.common_tools.tavily import tavily_search_tool
from pydantic_ai.messages import ModelMessage
from pydantic_ai.models.google import GoogleModel
from pydantic_ai.providers.google import GoogleProvider
from pydantic_ai.models.openai import OpenAIModel
from pydantic_ai.providers.openai import OpenAIProvider
from pydantic_ai.mcp import MCPServerStreamableHTTP, MCPServerSSE, MCPServerStdio
from dataclasses import dataclass
from datetime import datetime
from pydantic import Field
from google import genai
from google.genai import types


@dataclass
class Api_keys:
    api_keys: dict


@dataclass
class Message_state:
    messages: list[ModelMessage]

@dataclass
class Deps:
    agents_output: dict
    user:str
    
class Cortana_agent:
    def __init__(self, api_keys:dict):
        """
        Args:
            api_keys (dict): The API keys to use as a dictionary, the keys are:
            \n
            example:
            {
                'google_api_key': (str): The Google API key,

                'openai_api_key': (str): The OpenAI API key,

                'tavily_key': (str): The Tavily API key,

                'pse': (str): The Google Custom Search Engine ID,

                
            }
            mpc_server_urls (list): The list of dicts containing the url\n
            and the name of the mpc server and the type of connection, \n
            and the bearer token if necessary
              \n
              example:
              [
                {
                  'url': 'http://localhost:8000',
                  'name': 'mcp_server_1',
                  'type': 'http','SSE'
                  'headers': {'Authorization': 'Bearer 1234567890'} #optional or None
                }
              ]
            mpc_stdio_commands (list): The list of commands to use with the stdio mpc server
              \n
              example:
              [
                {
                  'name': 'memory',
                  'command': 'npx', 'docker', 'npm', 'python'
                  'args': ['-y', '@modelcontextprotocol/server-memory']
                }
              ]
        """
        
        self.api_keys=Api_keys(api_keys=api_keys)
        

        # tools
        llms={'pydantic_llm':GoogleModel('gemini-2.5-flash', provider=GoogleProvider(api_key=self.api_keys.api_keys['google_api_key'])),
              'mcp_llm':OpenAIModel('gpt-4.1-mini',provider=OpenAIProvider(api_key=self.api_keys.api_keys['openai_api_key']))}
    
        
        async def find_images_tool(ctx: RunContext[Deps],query:str):
            """Search for images using this tool, this tool can search one image at a time
            args: query
            return: image url
            """
            # Define the API endpoint for Google Custom Search
            url = "https://www.googleapis.com/customsearch/v1"
            

            params = {
                "q": query,
                "cx": self.api_keys.api_keys['pse'],
                "key": self.api_keys.api_keys['google_api_key'],
                "searchType": "image",  # Search for images
                "num": 1  # Number of results to fetch
            }

            # Make the request to the Google Custom Search API
            response = requests.get(url, params=params)
            data = response.json()

            # Check if the response contains image results
            if 'items' in data:
                # Extract the first image result
                image_url = data['items'][0]['link']
                res=f'image url for {query} : {image_url}'

                if not ctx.deps.agents_output.get('find_images_tool'):
                    ctx.deps.agents_output['find_images_tool']=[]

                ctx.deps.agents_output['find_images_tool'].append(image_url)

                if len(ctx.deps.agents_output['find_images_tool'])>5:
                    del ctx.deps.agents_output['find_images_tool'][0]
                return f'image url for {query} : {image_url}'
            else:
                return 'no image found'
                
        async def code_execution_tool(ctx: RunContext[Deps],query:str):
            """
            Use this tool to answer math questions or any other questions that require code execution, it can handle complex math problems and code execution.
            args: query (str): the detailed query 
            return: the result of the code execution
            """
            client = genai.Client(api_key=self.api_keys.api_keys['google_api_key'])

            response = client.models.generate_content(
                model="gemini-2.5-flash",
                contents=query,
                config=types.GenerateContentConfig(
                    tools=[types.Tool(code_execution=types.ToolCodeExecution)]
                ),
            )
            
            
            res={}
            for part in response.candidates[0].content.parts:
                if part.text is not None:
                    res['text']=part.text
                    
                if part.executable_code is not None:
                    res['code']=part.executable_code.code
                if part.code_execution_result is not None:
                    res['output']=part.code_execution_result.output
            ctx.deps.agents_output['code_execution_tool']=res

            
            return f'the result of the code execution is {res.get("output") if res.get("output") else "no result"}'
        

        #summarize old messages
        self.summarize_agent=Agent(llms['pydantic_llm'],instructions='Summarize this conversation, omitting small talk and unrelated topics. Focus on the technical discussion and next steps\
                                   keep the relevant information such as urls and ids.')
    
               

        #agent
        @dataclass
        class Cortana_output:
            ui_version: str= Field(description='a markdown format version of the answer for displays if necessary')
            voice_version: str = Field(description='a conversationnal version of the answer for text to voice')

        instructions = """
        # You are Cortana - A Helpful AI Assistant

        ## Your Role:
        You are Cortana, a helpful assistant capable of handling a wide range of tasks.

        ## Available Information:
        - Current time and date
        - User query and context
        - User's name (always refer to them by their first name)
        - Various tools and capabilities

        ## Tool Usage Guidelines:
        1. Before using any tools, explain what you plan to do and ask for user confirmation
        2. Only proceed with tool usage after the user says yes

        ## Communication Style:
        - Always address the user by their first name
        - Be clear and concise in explanations
        - Make suggestions on what to do next
        """

        self.agent=Agent(
            llms['mcp_llm'], 
            output_type=Cortana_output, 
            tools=[tavily_search_tool(self.api_keys.api_keys['tavily_key']), find_images_tool, code_execution_tool],
            
            instructions=instructions
        )
        self.memory=Message_state(messages=[])
        self.deps=Deps(agents_output={}, user='')
    
                  
    async def chat(self, query:any):
        """
        # Chat Function Documentation

        This function enables interaction with the user through various types of input.

        ## Parameters

        - `query`: The input to process. Can be one of the following types:
        - String: Direct text input passed to the agent
        - Binary content: Special format for media files (see below)

        ## Binary Content Types

        The function supports different types of media through `BinaryContent` objects:

        ### Audio
        ```python
        cortana_agent.chat([
            'optional string message',
            BinaryContent(data=audio, media_type='audio/wav')
        ])
        ```

        ### PDF Files
        ```python
        cortana_agent.chat([
            'optional string message',
            BinaryContent(data=pdf_path.read_bytes(), media_type='application/pdf')
        ])
        ```

        ### Images
        ```python
        cortana_agent.chat([
            'optional string message',
            BinaryContent(data=image_response.content, media_type='image/png')
        ])
        ```

        ## Returns

        - `Cortana_output`: as a pydantic object, the ui_version and voice_version are the two fields of the object

        ## Extra Notes
        The deps and message_history of cortana can be accessed using the following code:
        ```python
        cortana_agent.deps
        cortana_agent.memory.messages
        ```
        """
        result=await self.agent.run(query, deps=self.deps, message_history=self.memory.messages)
        
        
        if len(result.all_messages()) > 20:
                oldest_messages = result.all_messages()[:15]
                summary = await self.summarize_agent.run(f'oldest messages: {oldest_messages}')
                # Return the last message and the summary
                self.memory.messages=summary.new_messages() + result.new_messages()
        else:
            self.memory.messages=result.all_messages()

        return result
    
    def reset(self):
        """
        Resets the Cortana agent to its initial state.

        Returns:
            str: A confirmation message indicating that the agent has been reset.
        """
        self.memory.messages=[]
        self.deps=Deps(agents_output={}, user='')
        return f'Cortana has been reset'

# %%
import nest_asyncio
nest_asyncio.apply()
from dotenv import load_dotenv
import os
load_dotenv()
google_api_key = os.getenv("GOOGLE_API_KEY")
tavily_key = os.getenv("TAVILY_KEY")
openai_api_key = os.getenv("OPENAI_API_KEY")
pse = os.getenv("PSE")
composio_key = os.getenv("COMPOSIO_KEY")
hf_token = os.getenv("HF_TOKEN")
api_keys = {
    "google_api_key": google_api_key,
    "tavily_key": tavily_key,
    "openai_api_key": openai_api_key,
    "pse": pse,
    "composio_key": composio_key,
    "hf_token": hf_token
}

# %%
cortana_agent=Cortana_agent(api_keys=api_keys)

# %%
test_messages=['hello','how are you?','what is the weather in tokyo?','find me a picture of a cat','what is 10+14+15?']
test_messages2=['find a picture of an ant', 'what time is it?', 'multiply 10 by 14', 'how large is the moon?', 'name 5 us presidents']
for message in test_messages2:
    run=await cortana_agent.chat([message])
    print(run.output.ui_version)

# run=await cortana_agent.chat(['find me a picture of a cat'])
# print(run.output.ui_version)
# Out:
# Here is a picture of an ant: ![Ant](https://upload.wikimedia.org/wikipedia/commons/thumb/d/db/Red_Ant_-_March_2025.jpg/1200px-Red_Ant_-_March_2025.jpg)
# The current time is 19:24.
# 10 multiplied by 14 is 140.
# The Moon's mean radius is approximately 1,079.6 miles (1,737.5 kilometers), and its mean diameter is about 2,159.2 miles (3,475 kilometers). It is roughly one-quarter the size of Earth.
# Here are 5 U.S. Presidents: George Washington, Thomas Jefferson, Abraham Lincoln, Theodore Roosevelt, and John F. Kennedy.

# %%
run.usage().total_tokens
# Out:
# 7106

# %%
data=cortana_agent.memory.messages

# %%
data
# Out:
# [ModelRequest(parts=[UserPromptPart(content='oldest messages: [ModelRequest(parts=[UserPromptPart(content=[\'find a picture of an ant\'], timestamp=datetime.datetime(2025, 7, 23, 21, 24, 29, 226765, tzinfo=datetime.timezone.utc))], instructions="# You are Cortana - A Helpful AI Assistant\\n\\n        ## Your Role:\\n        You are Cortana, a helpful assistant capable of handling a wide range of tasks.\\n\\n        ## Available Information:\\n        - Current time and date\\n        - User query and context\\n        - User\'s name (always refer to them by their first name)\\n        - Various tools and capabilities\\n\\n        ## Tool Usage Guidelines:\\n        1. Before using any tools, explain what you plan to do and ask for user confirmation\\n        2. Only proceed with tool usage after the user says yes\\n\\n        ## Communication Style:\\n        - Always address the user by their first name\\n        - Be clear and concise in explanations\\n        - Make suggestions on what to do next"), ModelResponse(parts=[ToolCallPart(tool_name=\'tavily_search\', args=\'{"query":"ant image"}\', tool_call_id=\'call_2l99u7yxfvtC0TuVPmc9s7jl\')], usage=Usage(requests=1, request_tokens=456, response_tokens=17, total_tokens=473, details={\'accepted_prediction_tokens\': 0, \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\': 0, \'cached_tokens\': 0}), model_name=\'gpt-4.1-mini-2025-04-14\', timestamp=datetime.datetime(2025, 7, 23, 21, 24, 30, tzinfo=TzInfo(UTC)), vendor_id=\'chatcmpl-BwbEs7kufwgC9kp8hxCWa17wSKzYd\'), ModelRequest(parts=[ToolReturnPart(tool_name=\'tavily_search\', content=[{\'title\': \'Ant Pictures, Images and Stock Photos - iStock\', \'url\': \'https://www.istockphoto.com/photos/ant\', \'content\': \'Browse 81,100+ ant stock photos and images available, or search for ant farm or fire ant to find more great stock photos and pictures. ant farm · fire\', \'score\': 0.68064564}, {\'title\': \'Ant Cartoon Images – Browse 66995 Stock Photos, Vectors, and Video\', \'url\': \'https://stock.adobe.com/search/images?k=ant+cartoon\', \'content\': \'Search from thousands of royalty-free Ant Cartoon stock images and video for your next project. Download royalty-free stock photos, vectors, HD footage and\', \'score\': 0.6641271}, {\'title\': \'350+ Ant Pictures | Download Free Images on Unsplash\', \'url\': \'https://unsplash.com/s/photos/ant\', \'content\': \'Download the perfect ant pictures. Find over 100+ of the best free ant images. Free for commercial use ✓ No attribution required ✓ Copyright-free.\', \'score\': 0.6334335}, {\'title\': \'Ant Images - Free Download on Freepik\', \'url\': \'https://www.freepik.com/free-photos-vectors/ant\', \'content\': \'Find & Download Free Graphic Resources for Ant Vectors, Stock Photos & PSD files. ✓ Free for commercial use ✓ High Quality Images.\', \'score\': 0.6257817}, {\'title\': \'8197 Ant Close Up Stock Photos & High-Res Pictures - Getty Images\', \'url\': \'https://www.gettyimages.com/photos/ant-close-up\', \'content\': \'Browse 8,197 authentic ant close up stock photos, high-res images, and pictures, or explore additional ants or bee stock images to find the right photo at the\', \'score\': 0.6255073}], tool_call_id=\'call_2l99u7yxfvtC0TuVPmc9s7jl\', timestamp=datetime.datetime(2025, 7, 23, 21, 24, 34, 225290, tzinfo=datetime.timezone.utc))], instructions="# You are Cortana - A Helpful AI Assistant\\n\\n        ## Your Role:\\n        You are Cortana, a helpful assistant capable of handling a wide range of tasks.\\n\\n        ## Available Information:\\n        - Current time and date\\n        - User query and context\\n        - User\'s name (always refer to them by their first name)\\n        - Various tools and capabilities\\n\\n        ## Tool Usage Guidelines:\\n        1. Before using any tools, explain what you plan to do and ask for user confirmation\\n        2. Only proceed with tool usage after the user says yes\\n\\n        ## Communication S ...
#  ModelResponse(parts=[TextPart(content='The user made three distinct requests:\n\n1.  **Find a picture of an ant:**\n    *   The system first used `tavily_search` (call\\_2l99u7yxfvtC0TuVPmc9s7jl) to find "ant image", which returned several stock photo websites.\n    *   Subsequently, `find_images_tool` (call\\_somdl5BCJRCh1GJVA9qxOBlL) was called with the query "ant" and provided the direct image URL: `https://upload.wikimedia.org/wikipedia/commons/thumb/d/db/Red_Ant_-_March_2025.jpg/1200px-Red_Ant_-_March_2025.jpg`.\n    *   The final result (call\\_XqKJKqzX2eKpZ2jGIyoSlwnZ) presented this image.\n\n2.  **What time is it?:**\n    *   The system directly provided the current time as 19:24 via `final_result` (call\\_fMxsiZ5ThxDyC8yCH2rgs9Ee).\n\n3.  **Multiply 10 by 14:**\n    *   The `code_execution_tool` (call\\_3x7AmQRUgW2WnKOzTiZNtuyW) was used with the query "10 * 14".\n    *   The tool returned the result "140".\n    *   The final result (call\\_C5C76hJEZWHn7xLR4hU7zDi7) presented the multiplication result.')], usage=Usage(requests=1, request_tokens=3832, response_tokens=366, total_tokens=4749, details={'thoughts_tokens': 551, 'text_prompt_tokens': 3832}), model_name='gemini-2.5-flash', timestamp=datetime.datetime(2025, 7, 23, 21, 25, 2, 889868, tzinfo=datetime.timezone.utc), vendor_details={'finish_reason': 'STOP'}),
#  ModelRequest(parts=[UserPromptPart(content=['name 5 us presidents'], timestamp=datetime.datetime(2025, 7, 23, 21, 24, 53, 352154, tzinfo=datetime.timezone.utc))], instructions="# You are Cortana - A Helpful AI Assistant\n\n        ## Your Role:\n        You are Cortana, a helpful assistant capable of handling a wide range of tasks.\n\n        ## Available Information:\n        - Current time and date\n        - User query and context\n        - User's name (always refer to them by their first name)\n        - Various tools and capabilities\n\n        ## Tool Usage Guidelines:\n        1. Before using any tools, explain what you plan to do and ask for user confirmation\n        2. Only proceed with tool usage after the user says yes\n\n        ## Communication Style:\n        - Always address the user by their first name\n        - Be clear and concise in explanations\n        - Make suggestions on what to do next"),
#  ModelResponse(parts=[ToolCallPart(tool_name='tavily_search', args='{"query":"list of US presidents"}', tool_call_id='call_LJeZaAN7FZ3vOfGcep3g9UHi')], usage=Usage(requests=1, request_tokens=1902, response_tokens=19, total_tokens=1921, details={'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'cached_tokens': 0}), model_name='gpt-4.1-mini-2025-04-14', timestamp=datetime.datetime(2025, 7, 23, 21, 24, 53, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-BwbFF2kh4dALlYhq4kuaT5hbyI9s8'),
#  ModelRequest(parts=[ToolReturnPart(tool_name='tavily_search', content=[{'title': 'The Presidents of the United States', 'url': 'https://georgewbush-whitehouse.archives.gov/history/presidents/chronological.html', 'content': 'The Presidents of the United States =============== This is historical material, "frozen in time." Skip Main Navigation PRESIDENT | VICE PRESIDENT | FIRST LADY | MRS. CHENEY | NEWS Your Government | History & Tours | Kids | E-mail | En Español PodcastsRSS Feeds Tours In Person On-Line Panoramic Grounds & Garden Presidents & First Ladies Presidents First Ladies Kid Bios Kids Quiz White House Art Facts EEOB VP Residence Events & Traditions African-American History Month Presidents & Baseball Grounds and Garden Easter Egg Roll Christmas & Holidays State of the Union Resources Historical Association Presidential Libraries Military Air Force One Camp David Marine One Home>History & Tours>Past Presidents Presidents by Date ==================Presidents by NameView Flash Version Washington, George 1789-97 Adams, John 1797-1801 Jefferson, Thomas 1801-09 Madison, James 1809-17 Monroe, James 1817-25 Adams, John Quincy 1825-29 Jackson, Andrew 1829-37 Van Buren, Martin 1837-41 Harrison, William Henry 1841 Tyler, John 1841-45 Polk, James 1845-49 Taylor, Zachary 1849-50 Fillmore, Millard 1850-53 Pierce, Franklin 1853-57 Buchanan, James 1857-61 Lincoln, Abraham 1861-65 Johnson, Andrew 1865-69 Grant, Ulysses S. 1869-77 Hayes, Rutherford B. 1993-2001 Bush, George W. 2001- Oval Office Of the 42 presidents, only 17 have occupied the Oval Office. **Oval Office History Oval Office Photos 360-Degree Tour** More History Presidential History Video Highlight President Bush on Tuesday said, "Each of these gentlemen we honor today has his own style and personality, and each has amassed distinctions and achievements that belong to him alone.', 'score': 0.7969415}, {'title': 'List of presidents of the United States - Wikipedia', 'url': 'https://en.wikipedia.org/wiki/List_of_presidents_of_the_United_States', 'content': '| 13 | Image 19: Black-and-white photographic portrait of Millard Fillmore.jpg) | **Millard Fillmore** (1800–1874)  | July 9, 1850 – March 4, 1853 |  | Whig "Whig Party (United States)") | – | _Vacant throughout presidency_ | | 17 | Image 23: Black-and-white photographic portrait of Andrew Johnson.jpg) | **Andrew Johnson** (1808–1875)  | April 15, 1865 – March 4, 1869 |  | National Union "National Union Party (United States)") * * * Democratic "Democratic Party (United States)") | – | _Vacant throughout presidency_ | | 25 | Image 31: Black-and-white photographic portrait of William McKinley.jpg) | **William McKinley** (1843–1901) 2000-67) | March 4, 1897 – September 14, 1901 |  | Republican "Republican Party (United States)") | 1896 * * * 1900 | Garret Hobart * * * _Vacant after November 21, 1899_ * * * Theodore Roosevelt |', 'score': 0.7657514}, {'title': 'Selected Images: Chronological List of Presidents, First Spouses ...', 'url': 'https://guides.loc.gov/presidents-portraits/chronological', 'content': 'Chronological List of Presidents, First Spouses, and Vice Presidents of the United States - Presidents of the United States: Selected Images - Research Guides at Library of Congress | **1812-1813** | James Madison | Dolley Madison | office vacant | | **1814-1817** | James Madison | Dolley Madison | office vacant | | **1832-1833** | Andrew Jackson | Rachel Jackson | office vacant | Pierce | office vacant | | **1899-1901** | William McKinley | Ida Saxton McKinley | office vacant | | **1901-1905** | Theodore Roosevelt | Edith Kermit Carow Roosevelt | office vacant | Truman | Bess Wallace Truman | office vacant | Johnson | Lady Bird Johnson | office vacant |', 'score': 0.74785584}, {'title': 'Presidents of the United States of America - Ohio Secretary of State', 'url': 'https://www.ohiosos.gov/elections/election-results-and-data/historical-election-comparisons/presidents-of-the-united-states-of-america/', 'content': '| 10 | ...
#  ModelResponse(parts=[ToolCallPart(tool_name='final_result', args='{"ui_version":"Here are 5 U.S. Presidents: George Washington, Thomas Jefferson, Abraham Lincoln, Theodore Roosevelt, and John F. Kennedy.","voice_version":"Here are 5 U.S. Presidents: George Washington, Thomas Jefferson, Abraham Lincoln, Theodore Roosevelt, and John F. Kennedy."}', tool_call_id='call_vPW7BCOiKJFcvNNO178Cj03R')], usage=Usage(requests=1, request_tokens=3380, response_tokens=71, total_tokens=3451, details={'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'cached_tokens': 1152}), model_name='gpt-4.1-mini-2025-04-14', timestamp=datetime.datetime(2025, 7, 23, 21, 24, 55, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-BwbFHXdCoisJFZMPSpxmh3KvbjzDa'),
#  ModelRequest(parts=[ToolReturnPart(tool_name='final_result', content='Final result processed.', tool_call_id='call_vPW7BCOiKJFcvNNO178Cj03R', timestamp=datetime.datetime(2025, 7, 23, 21, 24, 58, 480544, tzinfo=datetime.timezone.utc))])]

# %%
from pydantic_ai.messages import UserPromptPart, ModelRequest, ModelResponse
messages=[]
for i in data :
    if isinstance(i,ModelRequest):
        if isinstance(i.parts[0].content,list):
            messages.append({'user_query':i.parts[0].content[0]})
        else:
            messages.append({'user_query':i.parts[0].content})
    elif isinstance(i,ModelResponse):
        messages.append({'model_response':i})

# %%
messages
# Out:
# [{'user_query': 'oldest messages: [ModelRequest(parts=[UserPromptPart(content=[\'find a picture of an ant\'], timestamp=datetime.datetime(2025, 7, 23, 21, 24, 29, 226765, tzinfo=datetime.timezone.utc))], instructions="# You are Cortana - A Helpful AI Assistant\\n\\n        ## Your Role:\\n        You are Cortana, a helpful assistant capable of handling a wide range of tasks.\\n\\n        ## Available Information:\\n        - Current time and date\\n        - User query and context\\n        - User\'s name (always refer to them by their first name)\\n        - Various tools and capabilities\\n\\n        ## Tool Usage Guidelines:\\n        1. Before using any tools, explain what you plan to do and ask for user confirmation\\n        2. Only proceed with tool usage after the user says yes\\n\\n        ## Communication Style:\\n        - Always address the user by their first name\\n        - Be clear and concise in explanations\\n        - Make suggestions on what to do next"), ModelResponse(parts=[ToolCallPart(tool_name=\'tavily_search\', args=\'{"query":"ant image"}\', tool_call_id=\'call_2l99u7yxfvtC0TuVPmc9s7jl\')], usage=Usage(requests=1, request_tokens=456, response_tokens=17, total_tokens=473, details={\'accepted_prediction_tokens\': 0, \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\': 0, \'cached_tokens\': 0}), model_name=\'gpt-4.1-mini-2025-04-14\', timestamp=datetime.datetime(2025, 7, 23, 21, 24, 30, tzinfo=TzInfo(UTC)), vendor_id=\'chatcmpl-BwbEs7kufwgC9kp8hxCWa17wSKzYd\'), ModelRequest(parts=[ToolReturnPart(tool_name=\'tavily_search\', content=[{\'title\': \'Ant Pictures, Images and Stock Photos - iStock\', \'url\': \'https://www.istockphoto.com/photos/ant\', \'content\': \'Browse 81,100+ ant stock photos and images available, or search for ant farm or fire ant to find more great stock photos and pictures. ant farm · fire\', \'score\': 0.68064564}, {\'title\': \'Ant Cartoon Images – Browse 66995 Stock Photos, Vectors, and Video\', \'url\': \'https://stock.adobe.com/search/images?k=ant+cartoon\', \'content\': \'Search from thousands of royalty-free Ant Cartoon stock images and video for your next project. Download royalty-free stock photos, vectors, HD footage and\', \'score\': 0.6641271}, {\'title\': \'350+ Ant Pictures | Download Free Images on Unsplash\', \'url\': \'https://unsplash.com/s/photos/ant\', \'content\': \'Download the perfect ant pictures. Find over 100+ of the best free ant images. Free for commercial use ✓ No attribution required ✓ Copyright-free.\', \'score\': 0.6334335}, {\'title\': \'Ant Images - Free Download on Freepik\', \'url\': \'https://www.freepik.com/free-photos-vectors/ant\', \'content\': \'Find & Download Free Graphic Resources for Ant Vectors, Stock Photos & PSD files. ✓ Free for commercial use ✓ High Quality Images.\', \'score\': 0.6257817}, {\'title\': \'8197 Ant Close Up Stock Photos & High-Res Pictures - Getty Images\', \'url\': \'https://www.gettyimages.com/photos/ant-close-up\', \'content\': \'Browse 8,197 authentic ant close up stock photos, high-res images, and pictures, or explore additional ants or bee stock images to find the right photo at the\', \'score\': 0.6255073}], tool_call_id=\'call_2l99u7yxfvtC0TuVPmc9s7jl\', timestamp=datetime.datetime(2025, 7, 23, 21, 24, 34, 225290, tzinfo=datetime.timezone.utc))], instructions="# You are Cortana - A Helpful AI Assistant\\n\\n        ## Your Role:\\n        You are Cortana, a helpful assistant capable of handling a wide range of tasks.\\n\\n        ## Available Information:\\n        - Current time and date\\n        - User query and context\\n        - User\'s name (always refer to them by their first name)\\n        - Various tools and capabilities\\n\\n        ## Tool Usage Guidelines:\\n        1. Before using any tools, explain what you plan to do and ask for user confirmation\\n        2. Only proceed with tool usage after the user says yes\\n\\n        ## Communication Style:\\n        - Always add ...
#  {'model_response': ModelResponse(parts=[TextPart(content='The user made three distinct requests:\n\n1.  **Find a picture of an ant:**\n    *   The system first used `tavily_search` (call\\_2l99u7yxfvtC0TuVPmc9s7jl) to find "ant image", which returned several stock photo websites.\n    *   Subsequently, `find_images_tool` (call\\_somdl5BCJRCh1GJVA9qxOBlL) was called with the query "ant" and provided the direct image URL: `https://upload.wikimedia.org/wikipedia/commons/thumb/d/db/Red_Ant_-_March_2025.jpg/1200px-Red_Ant_-_March_2025.jpg`.\n    *   The final result (call\\_XqKJKqzX2eKpZ2jGIyoSlwnZ) presented this image.\n\n2.  **What time is it?:**\n    *   The system directly provided the current time as 19:24 via `final_result` (call\\_fMxsiZ5ThxDyC8yCH2rgs9Ee).\n\n3.  **Multiply 10 by 14:**\n    *   The `code_execution_tool` (call\\_3x7AmQRUgW2WnKOzTiZNtuyW) was used with the query "10 * 14".\n    *   The tool returned the result "140".\n    *   The final result (call\\_C5C76hJEZWHn7xLR4hU7zDi7) presented the multiplication result.')], usage=Usage(requests=1, request_tokens=3832, response_tokens=366, total_tokens=4749, details={'thoughts_tokens': 551, 'text_prompt_tokens': 3832}), model_name='gemini-2.5-flash', timestamp=datetime.datetime(2025, 7, 23, 21, 25, 2, 889868, tzinfo=datetime.timezone.utc), vendor_details={'finish_reason': 'STOP'})},
#  {'user_query': 'name 5 us presidents'},
#  {'model_response': ModelResponse(parts=[ToolCallPart(tool_name='tavily_search', args='{"query":"list of US presidents"}', tool_call_id='call_LJeZaAN7FZ3vOfGcep3g9UHi')], usage=Usage(requests=1, request_tokens=1902, response_tokens=19, total_tokens=1921, details={'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'cached_tokens': 0}), model_name='gpt-4.1-mini-2025-04-14', timestamp=datetime.datetime(2025, 7, 23, 21, 24, 53, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-BwbFF2kh4dALlYhq4kuaT5hbyI9s8')},
#  {'user_query': {'title': 'The Presidents of the United States',
#    'url': 'https://georgewbush-whitehouse.archives.gov/history/presidents/chronological.html',
#    'content': 'The Presidents of the United States =============== This is historical material, "frozen in time." Skip Main Navigation PRESIDENT | VICE PRESIDENT | FIRST LADY | MRS. CHENEY | NEWS Your Government | History & Tours | Kids | E-mail | En Español PodcastsRSS Feeds Tours In Person On-Line Panoramic Grounds & Garden Presidents & First Ladies Presidents First Ladies Kid Bios Kids Quiz White House Art Facts EEOB VP Residence Events & Traditions African-American History Month Presidents & Baseball Grounds and Garden Easter Egg Roll Christmas & Holidays State of the Union Resources Historical Association Presidential Libraries Military Air Force One Camp David Marine One Home>History & Tours>Past Presidents Presidents by Date ==================Presidents by NameView Flash Version Washington, George 1789-97 Adams, John 1797-1801 Jefferson, Thomas 1801-09 Madison, James 1809-17 Monroe, James 1817-25 Adams, John Quincy 1825-29 Jackson, Andrew 1829-37 Van Buren, Martin 1837-41 Harrison, William Henry 1841 Tyler, John 1841-45 Polk, James 1845-49 Taylor, Zachary 1849-50 Fillmore, Millard 1850-53 Pierce, Franklin 1853-57 Buchanan, James 1857-61 Lincoln, Abraham 1861-65 Johnson, Andrew 1865-69 Grant, Ulysses S. 1869-77 Hayes, Rutherford B. 1993-2001 Bush, George W. 2001- Oval Office Of the 42 presidents, only 17 have occupied the Oval Office. **Oval Office History Oval Office Photos 360-Degree Tour** More History Presidential History Video Highlight President Bush on Tuesday said, "Each of these gentlemen we honor today has his own style and personality, and each has amassed distinctions and achievements that belong to him alone.',
#    'score': 0.7969415}},
#  {'model_response': ModelResponse(parts=[ToolCallPart(tool_name='final_result', args='{"ui_version":"Here are 5 U.S. Presidents: George Washington, Thomas Jefferson, Abraham Lincoln, Theodore Roosevelt, and John F. Kennedy.","voice_version":"Here are 5 U.S. Presidents: George Washington, Thomas Jefferson, Abraham Lincoln, Theodore Roosevelt, and John F. Kennedy."}', tool_call_id='call_vPW7BCOiKJFcvNNO178Cj03R')], usage=Usage(requests=1, request_tokens=3380, response_tokens=71, total_tokens=3451, details={'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'cached_tokens': 1152}), model_name='gpt-4.1-mini-2025-04-14', timestamp=datetime.datetime(2025, 7, 23, 21, 24, 55, tzinfo=TzInfo(UTC)), vendor_id='chatcmpl-BwbFHXdCoisJFZMPSpxmh3KvbjzDa')},
#  {'user_query': 'Final result processed.'}]
